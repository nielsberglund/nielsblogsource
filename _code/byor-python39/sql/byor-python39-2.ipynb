-- %% [markdown]
-- # Bring Python 3.9 to SQL Server Machine Learning Services - II
--
-- Let us register the extension:

-- %%
USE ExtLangDB;
GO
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.017

-- %%
DROP EXTERNAL LANGUAGE p39;
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.003

-- %%
USE ExtLangDB;
GO

CREATE EXTERNAL LANGUAGE p39
FROM (CONTENT = 'W:\python-lang-extension.zip'
      , FILE_NAME = 'pythonextension.dll');
GO
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.001

-- %%
SELECT * FROM sys.external_languages;
-- Out:
-- (3 rows affected)
-- Total execution time: 00:00:00.046
-- <table><tr><th>external_language_id</th><th>language</th><th>create_date</th><th>principal_id</th></tr><tr><td>1</td><td>R</td><td>2020-12-27 05:42:57.890</td><td>4</td></tr><tr><td>2</td><td>Python</td><td>2020-12-27 05:42:57.890</td><td>4</td></tr><tr><td>65539</td><td>p39</td><td>2021-01-04 17:12:34.513</td><td>1</td></tr></table>

-- %%
SELECT * FROM sys.external_language_files
-- Out:
-- (5 rows affected)
-- Total execution time: 00:00:00.021
-- <table><tr><th>external_language_id</th><th>content</th><th>file_name</th><th>platform</th><th>platform_desc</th><th>parameters</th><th>environment_variables</th></tr><tr><td>1</td><td>NULL</td><td>RLauncher.dll</td><td>1</td><td>WINDOWS</td><td>NULL</td><td>NULL</td></tr><tr><td>1</td><td>NULL</td><td>RLauncher.so</td><td>2</td><td>LINUX</td><td>NULL</td><td>NULL</td></tr><tr><td>2</td><td>NULL</td><td>PythonLauncher.dll</td><td>1</td><td>WINDOWS</td><td>NULL</td><td>NULL</td></tr><tr><td>2</td><td>NULL</td><td>PythonLauncher.so</td><td>2</td><td>LINUX</td><td>NULL</td><td>NULL</td></tr><tr><td>65536</td><td>...</td><td>pythonextension.dll</td><td>1</td><td>WINDOWS</td><td>NULL</td><td>NULL</td></tr></table>

-- %%
EXEC sp_execute_external_script
@language =N'p39',
@script=N'
import pandas as pd
import sys
df = pd.DataFrame(columns=["Version"])
ver = sys.version
df = df.append({"Version": ver}, ignore_index=True)
OutputDataSet = df'
WITH RESULT SETS (([Python Version] nvarchar(256)));
-- Out:
-- STDOUT message(s) from external script:
-- (1 row affected)
-- Total execution time: 00:00:04.219
-- <table><tr><th>Python Version</th></tr><tr><td>3.9.1 (tags/v3.9.1:1e5d33e, Dec  7 2020, 17:08:21) [MSC v.1927 64 bit (AMD64)]</td></tr></table>

-- %%
EXEC sp_execute_external_script
@language =N'p39',
@script=N'
print("Hello World")';
-- Out:
-- STDOUT message(s) from external script:
-- Hello World
-- Total execution time: 00:00:00.517

-- %%
USE ExtLangDB;
GO

CREATE EXTERNAL LANGUAGE p379dbg
FROM (CONTENT = 'W:\python-lang-extension-windows-debug.zip'
      , FILE_NAME = 'pythonextension.dll');
GO
-- Out:
-- Commands completed successfully.
-- Commands completed successfully.
-- Total execution time: 00:00:00.002
